# %% [markdown]
# # EDA

# %% [markdown]
# #### Importing clean data

# %%
import pandas as pd

# %%
df =pd.read_csv("df_clean.csv")

# %%
df
# Out:
#             district                                    address  \
# 0          grunewald                          Grunewald, Berlin
# 1              mitte  Gartenstraße 88, Mitte (Ortsteil), Berlin
# 2              karow          Drei-Linien-Weg 99, Karow, Berlin
# 3     charlottenburg   Witzlebenplatz 2, Charlottenburg, Berlin
# 4         tiergarten     Flottwellstraße 24, Tiergarten, Berlin
# ...              ...                                        ...
# 3480       kaulsdorf    Wilhelmsmühlenweg 12, Kaulsdorf, Berlin
# 3481      schöneberg      Nollendorfstr. 17, Schöneberg, Berlin
# 3482           tegel                              Tegel, Berlin
# 3483      tiergarten     Potsdamer Str. 100, Tiergarten, Berlin
# 3484  charlottenburg       Kaiserdamm 6, Charlottenburg, Berlin
#
#                                             description  total rent    area  \
# 0                     Exklusives Penthouse im Grunewald     3940.00  175.00
# ...
